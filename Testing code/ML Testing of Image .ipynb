# %%
import h5py
from tensorflow.keras.models import load_model
import cv2  
import numpy as np
# Out:
# /home/rahetul/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/rahetul/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/rahetul/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
model = load_model('model.h5')
# Out:
# WARNING:tensorflow:From /home/rahetul/.local/lib/python3.6/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
img = cv2.imread('2019-11-26-055106.jpg')

# %%
i3= cv2.imread('IMG_0124-01.jpeg')

# %%
size = (150,150)
i3= cv2.resize(i3, size)

# %%
size = (150,150)
img = cv2.resize(img, size)

# %%
img = np.array(img, dtype = 'float32')

# %%
i3=np.array(i3, dtype = 'float32')

# %%
i33 = i3.reshape((-1, 150, 150, 3))

# %%
img1 = img.reshape((-1, 150, 150, 3))

# %%
img=img / 255.0

# %%
model.summary
# Out:
# <bound method Network.summary of <tensorflow.python.keras.engine.sequential.Sequential object at 0x7f6f82725e80>>

# %%
predictions = model.predict(img1)

# %%
predictions3 = model.predict(i33)

# %%
predictions

# %%
from keras.preprocessing import image
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
plt.imshow(img/256.)

# %%
plt.imshow(i3/256.)

# %%
plt.imshow(predictions3/256.)

# %%
plt.imshow(predictions/256.)

# %%
img_class=model.predict_classes(img1)

# %%
prediction = img_class[0]

# %%
classname = img_class[0]

# %%
print("Class: ",classname)
# Out:
# Class:  3

# %%
img_class=model.predict_classes(i33)
prediction = img_class[0]
classname = img_class[0]
print("Class: ",classname)
# Out:
# Class:  3

# %%
i4= cv2.imread('466.jpg')
size = (150,150)
i4= cv2.resize(i4, size)
i4=np.array(i4, dtype = 'float32')

# %%
i44 = i4.reshape((-1, 150, 150, 3))

# %%
predictions4 = model.predict(i44)

# %%
plt.imshow(i4/256.)

# %%
plt.imshow(predictions4/256.)

# %%
img_class=model.predict_classes(i44)
prediction = img_class[0]
classname = img_class[0]
print("Class: ",classname)
# Out:
# Class:  5
